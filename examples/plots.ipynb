# %%
import sys
sys.path.append("/home/davidwang/code_repos/dldsc")

# %%
import pandas as pd
import torch

# %%
from src.plot.finemapping_plots import plot_finemapping
from src.plot.finemapping_plots import plot_priors

# %%
data = pd.read_parquet("/scratch4/davidwang/examples/output/chr1_208000001_211000001.parquet")

# %%
plot_finemapping(torch.tensor(data["body_HEIGHTz_PIP"].values))

# %%
plot_priors(torch.tensor(data["body_HEIGHTz_prior"].values), index=[3241])
